# %%
import pandas as pd
pd.set_option('display.max_columns', None)

df = pd.read_csv("mo_features.csv")
display(df)
# Out:
#    FV_avg_avg  FV_avg_sd  FV_sd_avg  FV_sd_sd  FV_r1_avg  FV_r1_sd  FV_kr_avg  \
# 0    0.118302   0.081382   0.094711  0.073448   0.395217  0.343796   1.981712
#
#    FV_kr_sd  FV_sk_avg  FV_sk_sd  FD_avg_avg  FD_avg_sd  FD_sd_avg  FD_sd_sd  \
# 0  0.474261   0.274168  0.384573    -0.03328   0.033754   0.077327   0.06079
#
#    FD_r1_avg  FD_r1_sd  FD_kr_avg  FD_kr_sd  FD_sk_avg  FD_sk_sd  IN_avg_avg  \
# 0  -0.280551  0.282683   2.706232  1.024145   0.313196  0.828731      0.3375
#
#    IN_avg_sd  IN_sd_avg  IN_sd_sd  IN_r1_avg  IN_r1_sd  IN_kr_avg  IN_kr_sd  \
# 0   0.118454   0.367615  0.066496  -0.214186  0.341273   2.461449  1.246524
#
#    IN_sk_avg  IN_sk_sd
# 0   0.791822  0.604016

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 30 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   FV_avg_avg  1 non-null      float64
#  1   FV_avg_sd   1 non-null      float64
#  2   FV_sd_avg   1 non-null      float64
#  3   FV_sd_sd    1 non-null      float64
#  4   FV_r1_avg   1 non-null      float64
#  5   FV_r1_sd    1 non-null      float64
#  6   FV_kr_avg   1 non-null      float64
#  7   FV_kr_sd    1 non-null      float64
#  8   FV_sk_avg   1 non-null      float64
#  9   FV_sk_sd    1 non-null      float64
#  10  FD_avg_avg  1 non-null      float64
#  11  FD_avg_sd   1 non-null      float64
#  12  FD_sd_avg   1 non-null      float64
#  13  FD_sd_sd    1 non-null      float64
#  14  FD_r1_avg   1 non-null      float64
#  15  FD_r1_sd    1 non-null      float64
#  16  FD_kr_avg   1 non-null      float64
#  17  FD_kr_sd    1 non-null      float64
# ...
