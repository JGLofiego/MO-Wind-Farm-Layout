# %%
import pandas as pd
pd.set_option('display.max_columns', None)

df = pd.read_csv("mo_features.csv")
display(df)
# Out:
#      FV_avg_avg     FV_avg_sd      FV_sd_avg       FV_sd_sd  FV_r1_avg  \
# 0  3.244987e+06  2.597756e+06  949788.587087  976399.677706  -0.308075
#
#    FV_r1_sd  FV_kr_avg  FV_kr_sd  FV_sk_avg  FV_sk_sd  FD_avg_avg  FD_avg_sd  \
# 0  0.755341   1.343567  0.402843   0.050967  0.270162    0.735541   0.975049
#
#    FD_sd_avg  FD_sd_sd  FD_r1_avg  FD_r1_sd  FD_kr_avg  FD_kr_sd  FD_sk_avg  \
# 0   0.865038  1.262101  -0.473351  0.697894   2.306504  2.337803   0.546233
#
#    FD_sk_sd  IN_avg_avg  IN_avg_sd  IN_sd_avg  IN_sd_sd  IN_r1_avg  IN_r1_sd  \
# 0  0.966836    0.448667   0.164872   0.145777  0.075142   -0.38612  0.640186
#
#    IN_kr_avg  IN_kr_sd  IN_sk_avg  IN_sk_sd
# 0        NaN       NaN        NaN       NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 30 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   FV_avg_avg  1 non-null      float64
#  1   FV_avg_sd   1 non-null      float64
#  2   FV_sd_avg   1 non-null      float64
#  3   FV_sd_sd    1 non-null      float64
#  4   FV_r1_avg   1 non-null      float64
#  5   FV_r1_sd    1 non-null      float64
#  6   FV_kr_avg   1 non-null      float64
#  7   FV_kr_sd    1 non-null      float64
#  8   FV_sk_avg   1 non-null      float64
#  9   FV_sk_sd    1 non-null      float64
#  10  FD_avg_avg  1 non-null      float64
#  11  FD_avg_sd   1 non-null      float64
#  12  FD_sd_avg   1 non-null      float64
#  13  FD_sd_sd    1 non-null      float64
#  14  FD_r1_avg   1 non-null      float64
#  15  FD_r1_sd    1 non-null      float64
#  16  FD_kr_avg   1 non-null      float64
#  17  FD_kr_sd    1 non-null      float64
# ...
